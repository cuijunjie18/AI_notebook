# %% [markdown]
# **使用VGG模型进行图像分类**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **一、数据预处理**

# %%
from frame_special import *
import numpy as np
import torchinfo

# %%
# 加载原始数据
train_arrays,train_labels = load_data()
test_arrays = load_test()
# Out:
# Load train data: 100%|██████████| 50000/50000 [00:06<00:00, 7378.50it/s]
# Load test data: 100%|██████████| 300000/300000 [00:21<00:00, 13638.23it/s]

# %%
# 构造训练数据迭代器
batch_size = 64
train_dataset = TrainDataset(train_arrays,train_labels)
train_iter = data.DataLoader(train_dataset,batch_size,shuffle = True)
# Out:
# Load-Data-iter: 100%|██████████| 50000/50000 [00:03<00:00, 12519.09it/s]
# load 50000 images!

# %%
# 构造测试数据迭代器
test_dataset = TestDataset(test_arrays)
test_iter = data.DataLoader(test_dataset,batch_size,shuffle = False)
# Out:
# Load-Data-iter: 100%|██████████| 300000/300000 [00:19<00:00, 15744.98it/s]
# load 300000 images!

# %% [markdown]
# **二，VGG网络搭建**

# %%
def vgg_block(num_convs,in_channels,out_channels) -> nn.Sequential:
    """单个vgg块的生成"""
    layers = []
    for _ in range(num_convs):
        layers.append(nn.Conv2d(in_channels,out_channels,
                                kernel_size = 3,padding = 1)) # 保持宽高
        layers.append(nn.ReLU())
        in_channels = out_channels
    layers.append(nn.MaxPool2d(kernel_size = 2,stride = 2)) # 分辨率减半
    return nn.Sequential(*layers)

# %%
def vgg(conv_arch,in_H = 32,in_W = 32,class_nums = 10):
    """我的vgg网络，VGG-11加上一个softmax，处理分类问题"""
    conv_blks = []
    in_channels = 3     #初始为rgb三通道
    for num_convs,out_channels in conv_arch:
        conv_blks.append(vgg_block(num_convs,in_channels,out_channels))
        in_channels = out_channels
        in_H = int(in_H / 2)
        in_W = int(in_W / 2)
    return nn.Sequential(
        *conv_blks,nn.Flatten(),
        nn.Linear(out_channels * in_H * in_W,4096),nn.ReLU(),nn.Dropout(0.5),
        nn.Linear(4096,4096),nn.ReLU(),nn.Dropout(0.5),
        nn.Linear(4096,class_nums),nn.Softmax(dim = 1)
                         )

# %%
conv_arch = ((1,64),(1,128),(2,256),(2,512),(2,512))
object_map = get_map()
net = vgg(conv_arch)

# %%
# 构造输入，测试模型
input = torch.rand((1,3,32,32))
torchinfo.summary(net,input.shape)
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Sequential                               [1, 10]                   --
# ├─Sequential: 1-1                        [1, 64, 16, 16]           --
# │    └─Conv2d: 2-1                       [1, 64, 32, 32]           1,792
# │    └─ReLU: 2-2                         [1, 64, 32, 32]           --
# │    └─MaxPool2d: 2-3                    [1, 64, 16, 16]           --
# ├─Sequential: 1-2                        [1, 128, 8, 8]            --
# │    └─Conv2d: 2-4                       [1, 128, 16, 16]          73,856
# │    └─ReLU: 2-5                         [1, 128, 16, 16]          --
# │    └─MaxPool2d: 2-6                    [1, 128, 8, 8]            --
# ├─Sequential: 1-3                        [1, 256, 4, 4]            --
# │    └─Conv2d: 2-7                       [1, 256, 8, 8]            295,168
# │    └─ReLU: 2-8                         [1, 256, 8, 8]            --
# │    └─Conv2d: 2-9                       [1, 256, 8, 8]            590,080
# │    └─ReLU: 2-10                        [1, 256, 8, 8]            --
# │    └─MaxPool2d: 2-11                   [1, 256, 4, 4]            --
# ├─Sequential: 1-4                        [1, 512, 2, 2]            --
# │    └─Conv2d: 2-12                      [1, 512, 4, 4]            1,180,160
# │    └─ReLU: 2-13                        [1, 512, 4, 4]            --
# │    └─Conv2d: 2-14                      [1, 512, 4, 4]            2,359,808
# │    └─ReLU: 2-15                        [1, 512, 4, 4]            --
# │    └─MaxPool2d: 2-16                   [1, 512, 2, 2]            --
# ├─Sequential: 1-5                        [1, 512, 1, 1]            --
# │    └─Conv2d: 2-17                      [1, 512, 2, 2]            2,359,808
# │    └─ReLU: 2-18                        [1, 512, 2, 2]            --
# │    └─Conv2d: 2-19                      [1, 512, 2, 2]            2,359,808
# │    └─ReLU: 2-20                        [1, 512, 2, 2]            --
# │    └─MaxPool2d: 2-21                   [1, 512, 1, 1]            --
# ├─Flatten: 1-6                           [1, 512]                  --
# ├─Linear: 1-7                            [1, 4096]                 2,101,248
# ├─ReLU: 1-8                              [1, 4096]                 --
# ├─Dropout: 1-9                           [1, 4096]                 --
# ├─Linear: 1-10                           [1, 4096]                 16,781,312
# ├─ReLU: 1-11                             [1, 4096]                 --
# ├─Dropout: 1-12                          [1, 4096]                 --
# ├─Linear: 1-13                           [1, 10]                   40,970
# ├─Softmax: 1-14                          [1, 10]                   --
# ==========================================================================================
# Total params: 28,144,010
# Trainable params: 28,144,010
# Non-trainable params: 0
# Total mult-adds (M): 171.84
# ==========================================================================================
# Input size (MB): 0.01
# Forward/backward pass size (MB): 1.28
# Params size (MB): 112.58
# Estimated Total Size (MB): 113.87
# ==========================================================================================

# %% [markdown]
# **三、模型训练**

# %%
# 定义超参数
num_epochs = 50
lr = 3e-5

# 损失函数
loss_fn = nn.CrossEntropyLoss()

# %%
loss_plt = train(net,train_iter,lr,num_epochs,loss_fn)
# Out:
# Epoch [1/50]:  96%|█████████▌| 752/782 [00:12<00:00, 59.30it/s, LOSS=0.0344]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 loss_plt = train(net,train_iter,lr,num_epochs,loss_fn)
#
# File /data_all/cjj_node/kaggle/CIFAR-10-object-reconize/frame_special.py:139, in train(net, train_iter, lr, num_epochs, loss_fn)
#     137 y_pred = net(X)
#     138 loss = loss_fn(y_pred,Y)
# --> 139 loss.sum().backward()
#     140 optimzer.step()
#     142 loss_temp += loss.sum().item()
#
# File /data_all/cjj_node/local/anaconda3/envs/QwenLM/lib/python3.10/site-packages/torch/_tensor.py:521, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     511 if has_torch_function_unary(self):
#     512     return handle_torch_function(
#     513         Tensor.backward,
#     514         (self,),
#    (...)
#     519         inputs=inputs,
#     520     )
# --> 521 torch.autograd.backward(
#     522     self, gradient, retain_graph, create_graph, inputs=inputs
#     523 )
#
# File /data_all/cjj_node/local/anaconda3/envs/QwenLM/lib/python3.10/site-packages/torch/autograd/__init__.py:289, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     284     retain_graph = create_graph
#     286 # The reason we repeat the same comment below is that
#     287 # some Python versions print out the first line of a multi-line function
#     288 # calls in the traceback and some print out the last line
# --> 289 _engine_run_backward(
#     290     tensors,
#     291     grad_tensors_,
#     292     retain_graph,
#     293     create_graph,
#     294     inputs,
#     295     allow_unreachable=True,
#     296     accumulate_grad=True,
#     297 )
#
# File /data_all/cjj_node/local/anaconda3/envs/QwenLM/lib/python3.10/site-packages/torch/autograd/graph.py:768, in _engine_run_backward(t_outputs, *args, **kwargs)
#     766     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     767 try:
# --> 768     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     769         t_outputs, *args, **kwargs
#     770     )  # Calls into the C++ engine to run the backward pass
#     771 finally:
#     772     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
# 训练损失展示
import matplotlib.pyplot as plt
plt.plot(np.arange(len(loss_plt)),loss_plt)
plt.show()

# %%
# 保存模型
torch.save(net,"models/vgg11-4.pt")
print(f"model save successfully!")
# Out:
# model save successfully!

# %% [markdown]
# **四、模型评估**

# %%
def count_accurancy(net,train_iter):
    """训练集上准确率测试"""
    device = try_gpu(i = 0)
    net.eval()
    net.to(device)
    total_nums = 0
    ans = 0
    loop = tqdm(train_iter,total = len(train_iter),desc = "Eval")
    for X,Y in loop:
        total_nums += X.shape[0]
        X = X.to(device)
        Y = Y.to(device).argmax(dim = 1)
        # print(X.shape,Y.shape)
        y_pred = net(X).argmax(dim = 1)
        # print(y_pred.shape)
        ans += (y_pred == Y).sum().item()
    return ans / total_nums

# %%
net = torch.load("models/vgg11-4.pt",weights_only = False)
acc = count_accurancy(net,train_iter)
print(acc)
# Out:
# Eval: 100%|██████████| 782/782 [00:02<00:00, 290.97it/s]
# 0.93386

# %%
# 在验证集上测试
predict(net,test_iter,train_dataset.idx2obj)
# Out:
# Predict: 100%|██████████| 4688/4688 [00:10<00:00, 444.39it/s]
