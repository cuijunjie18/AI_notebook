# %%
#本次代码块运用的图片展示

# %% [markdown]
# ![lena.jpg](attachment:lena.jpg)

# %%
#导入必要模块
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
#显示图像

img = cv2.imread("images\lena.jpg")
cv2.imshow("Lena",img)
cv2.waitKey(0)
cv2.destroyAllwindows()
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\l'
# <>:3: SyntaxWarning: invalid escape sequence '\l'
# C:\Users\28718\AppData\Local\Temp\ipykernel_15956\3638900471.py:3: SyntaxWarning: invalid escape sequence '\l'
#   img = cv2.imread("images\lena.jpg")
